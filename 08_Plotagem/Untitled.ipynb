# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotagem

# %%
# Plotagem básica: plot
dados = pd.Series(np.random.randn(15), index=pd.date_range('1/1/2000', periods=15))
dados
# Out:
# 2000-01-01   -1.547757
# 2000-01-02    1.201975
# 2000-01-03    0.245895
# 2000-01-04    1.982573
# 2000-01-05   -0.059997
# 2000-01-06    0.010414
# 2000-01-07    0.971677
# 2000-01-08    0.067583
# 2000-01-09   -0.530873
# 2000-01-10   -0.509538
# 2000-01-11   -0.102216
# 2000-01-12   -0.846342
# 2000-01-13    0.135382
# 2000-01-14   -0.409533
# 2000-01-15    0.895828
# Freq: D, dtype: float64

# %%
dados.plot()
# Out:
# <AxesSubplot:>

# %%
# No DataFrame, plot()é conveniente plotar todas as colunas com rótulos:
df = pd.DataFrame(np.random.randn(15,4), index=dados.index, columns=list('ABCD'))
df.cumsum()
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Você pode representar uma coluna em comparação com outra usando as palavras x- ychave e em plot():
df = pd.DataFrame(np.random.randn(1000, 2), columns=['A', 'B']).cumsum()
df['A'] = pd.Series(list(range(len(df))))
df.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
# Chamar o plot.bar()método de DataFrame produz um gráfico de várias barras:
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Para produzir um gráfico de barras empilhadas, passe stacked=True:
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
# Para obter gráficos de barra horizontal, use o barhmétodo:
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogramas

# %%
df = pd.DataFrame({
    "a": np.random.randn(1000) + 1,
    "b": np.random.randn(1000),
    "c": np.random.randn(1000) - 1,
},columns=["a", "b", "c"],)
plt.figure()
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>
